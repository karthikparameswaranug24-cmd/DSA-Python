# %% [markdown]
# # Intro

# %% [markdown]
# String creation:

# %%
str1 = 'This is a string in Python'
print(str1)
print(type(str1))
# Out:
# This is a string in Python
# <class 'str'>

# %%
str2 = "This is a string in Python"
print(str2)
print(type(str2))
# Out:
# This is a string in Python
# <class 'str'>

# %%
str3 = '''This is a string in Python'''
print(str3)
print(type(str3))
# Out:
# This is a string in Python
# <class 'str'>

# %%
str4 = """This is a string in Python"""
print(str4)
print(type(str4))
# Out:
# This is a string in Python
# <class 'str'>

# %%
print("Hi 'John'")
# Out:
# Hi 'John'

# %%
print('''This is a 
multi-line string that 
spans multiple lines''')
# Out:
# This is a
# multi-line string that
# spans multiple lines

# %%
# Trying to use single quotes for multi line strings:
print('This is a \
multi-line string that \
spans multiple lines')
# Out:
# This is a multi-line string that spans multiple lines

# %% [markdown]
# ## Accessing characters in a string:

# %%
str1
# Out:
# 'This is a string in Python'

# %%
str1[0]
# Out:
# 'T'

# %%
str1[-1]
# Out:
# 'n'

# %%
str1[2:10]
# Out:
# 'is is a '

# %%
str1[4:10]
# Out:
# ' is a '
