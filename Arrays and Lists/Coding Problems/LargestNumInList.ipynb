# %%
arr = [1, 2, 3, 4, 5]

# %% [markdown]
# ## Approach-1:-

# %%
print(max(arr))
# Out:
# 5

# %% [markdown]
# ## Approach-2:-

# %%
n = len(arr)
maxi = arr[0]
for i in range(1, n):
  if arr[i] > maxi:
    maxi = arr[i]
print(maxi)
# Out:
# 5
